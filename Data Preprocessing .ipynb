# %% [markdown]
# # GLOBAL TERRORISM DATABASE

# %%
import pandas as pd
import numpy as np
import warnings
# Configure notebook output
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# Number of rows and columns
pd.set_option('display.max_rows', 150)
pd.set_option('display.max_columns', 150)

# %% [markdown]
# ### Load the Datasets
# For this project, we will import one dataset are imported which covers the years 1997 to 2017.

# %%
pwd
# Out:
# '/Users/ramv/Downloads/Capstone/Notebook'

# %%
# Load 1996-2013 GTD
# Read in the data which is in  excel format.   
gtd_df1 = pd.read_excel('../Data/gtd_96to13.xlsx', index_col = 0,
                      na_values=[''])

# Load 2014-2017 GTD
gtd_df2 = pd.read_excel('../Data/gtd_14to17.xlsx', index_col = 0, 
                      na_values=[''])

# Append the 2nd data frame to the first
gtd_df = gtd_df1.append(gtd_df2)

# %% [markdown]
# ### Inspect the Structure
# The data frame contains 134 attributes, one of which is used for the data frame index, and 181691 observations.

# %%
import pandas_profiling
# #Html Report
profile = gtd_df.profile_report(style={'full_width':False},correlations={"cramers": False})
profile.to_file(output_file="Global Terrorism Data.html")

# %%
# Display a summary of the data frame
gtd_df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120439 entries, 199601000001 to 201712310032
# Data columns (total 134 columns):
# iyear                 int64
# imonth                int64
# iday                  int64
# approxdate            object
# extended              int64
# resolution            object
# country               int64
# country_txt           object
# region                int64
# region_txt            object
# provstate             object
# city                  object
# latitude              float64
# longitude             float64
# specificity           float64
# vicinity              int64
# location              object
# summary               object
# crit1                 int64
# crit2                 int64
# crit3                 int64
# doubtterr             float64
# alternative           float64
# alternative_txt       object
# multiple              float64
# success               int64
# suicide               int64
# attacktype1           int64
# attacktype1_txt       object
# attacktype2           float64
# attacktype2_txt       object
# attacktype3           float64
# attacktype3_txt       object
# targtype1             int64
# targtype1_txt         object
# targsubtype1          float64
# targsubtype1_txt      object
# corp1                 object
# target1               object
# natlty1               float64
# natlty1_txt           object
# targtype2             float64
# targtype2_txt         object
# targsubtype2          float64
# targsubtype2_txt      object
# corp2                 object
# target2               object
# natlty2               float64
# natlty2_txt           object
# targtype3             float64
# targtype3_txt         object
# targsubtype3          float64
# targsubtype3_txt      object
# corp3                 object
# target3               object
# natlty3               float64
# natlty3_txt           object
# gname                 object
# gsubname              object
# gname2                object
# gsubname2             object
# gname3                object
# gsubname3             object
# motive                object
# guncertain1           float64
# guncertain2           float64
# guncertain3           float64
# individual            int64
# nperps                float64
# nperpcap              float64
# claimed               float64
# claimmode             float64
# claimmode_txt         object
# claim2                float64
# claimmode2            float64
# claimmode2_txt        object
# claim3                float64
# claimmode3            float64
# claimmode3_txt        object
# compclaim             float64
# weaptype1             int64
# weaptype1_txt         object
# weapsubtype1          float64
# weapsubtype1_txt      object
# weaptype2             float64
# weaptype2_txt         object
# weapsubtype2          float64
# weapsubtype2_txt      object
# weaptype3             float64
# weaptype3_txt         object
# weapsubtype3          float64
# weapsubtype3_txt      object
# weaptype4             float64
# weaptype4_txt         object
# weapsubtype4          float64
# weapsubtype4_txt      object
# weapdetail            object
# nkill                 float64
# nkillus               float64
# nkillter              float64
# nwound                float64
# nwoundus              float64
# nwoundte              float64
# property              int64
# propextent            float64
# propextent_txt        object
# propvalue             float64
# propcomment           object
# ishostkid             float64
# nhostkid              float64
# nhostkidus            float64
# nhours                float64
# ndays                 float64
# divert                object
# kidhijcountry         object
# ransom                float64
# ransomamt             float64
# ransomamtus           float64
# ransompaid            float64
# ransompaidus          float64
# ransomnote            object
# hostkidoutcome        float64
# hostkidoutcome_txt    object
# nreleased             float64
# addnotes              object
# scite1                object
# scite2                object
# scite3                object
# dbsource              object
# INT_LOG               int64
# INT_IDEO              int64
# INT_MISC              int64
# INT_ANY               int64
# related               object
# dtypes: float64(55), int64(21), object(58)
# memory usage: 124.0+ MB

# %% [markdown]
# ### View Missing Data
# Calculate the total number of null values and percent for each attribute.  As the results show, many attributes are comprised of missing values of more than 50%.

# %%
# Check the number of missing values in each attribute
count = gtd_df.isnull().sum()
percent = round(count / 120439 * 100, 2)
series = [count, percent]
result = pd.concat(series, axis=1, keys=['Count','Percent'])
result.sort_values(by='Count', ascending=False)
# Out:
#                      Count  Percent
# weaptype4           120434   100.00
# weaptype4_txt       120434   100.00
# weapsubtype4_txt    120433   100.00
# weapsubtype4        120433   100.00
# gsubname3           120419    99.98
# claimmode3_txt      120314    99.90
# claimmode3          120314    99.90
# gsubname2           120281    99.87
# divert              120275    99.86
# guncertain3         120130    99.74
# claim3              120129    99.74
# gname3              120126    99.74
# attacktype3         120014    99.65
# attacktype3_txt     120014    99.65
# ransomnote          119931    99.58
# ransompaidus        119891    99.54
# ransomamtus         119877    99.53
# claimmode2_txt      119841    99.50
# claimmode2          119841    99.50
# ransompaid          119802    99.47
# kidhijcountry       119726    99.41
# ransomamt           119690    99.38
# corp3               119473    99.20
# targsubtype3        119419    99.15
# targsubtype3_txt    119419    99.15
# natlty3_txt         119392    99.13
# natlty3             119392    99.13
# targtype3           119364    99.11
# targtype3_txt       119364    99.11
# target3             119363    99.11
# resolution          119308    99.06
# weapsubtype3        119098    98.89
# weapsubtype3_txt    119098    98.89
# weaptype3_txt       118988    98.80
# weaptype3           118988    98.80
# guncertain2         118624    98.49
# claim2              118569    98.45
# gname2              118566    98.44
# nhours              117610    97.65
# gsubname            116970    97.12
# compclaim           115653    96.03
# attacktype2_txt     114175    94.80
# attacktype2         114175    94.80
# ndays               113272    94.05
# weapsubtype2_txt    111664    92.71
# weapsubtype2        111664    92.71
# approxdate          111228    92.35
# nreleased           111154    92.29
# hostkidoutcome_txt  110906    92.08
# hostkidoutcome      110906    92.08
# corp2               110738    91.95
# weaptype2_txt       110642    91.87
# weaptype2           110642    91.87
# nhostkidus          110608    91.84
# nhostkid            110553    91.79
# targsubtype2_txt    110243    91.53
# targsubtype2        110243    91.53
# natlty2_txt         110200    91.50
# natlty2             110200    91.50
# target2             109994    91.33
# targtype2_txt       109951    91.29
# targtype2           109951    91.29
# ransom              103945    86.31
# claimmode_txt       101692    84.43
# claimmode           101692    84.43
# related             101474    84.25
# alternative_txt     101347    84.15
# alternative         101347    84.15
# addnotes             93176    77.36
# propvalue            91477    75.95
# scite3               77776    64.58
# propextent_txt       73506    61.03
# propextent           73506    61.03
# motive               70924    58.89
# location             65752    54.59
# propcomment          65541    54.42
# weapdetail           61850    51.35
# scite2               44698    37.11
# nperps               18477    15.34
# corp1                13165    10.93
# weapsubtype1_txt     10733     8.91
# weapsubtype1         10733     8.91
# nwoundte             10665     8.86
# nperpcap              9568     7.94
# nkillter              8820     7.32
# nwound                8523     7.08
# targsubtype1          7600     6.31
# targsubtype1_txt      7600     6.31
# nwoundus              6620     5.50
# nkillus               6414     5.33
# scite1                6268     5.20
# summary               6206     5.15
# claimed               6204     5.15
# nkill                 4404     3.66
# latitude              1284     1.07
# longitude             1284     1.07
# natlty1_txt           1209     1.00
# natlty1               1209     1.00
# city                   434     0.36
# guncertain1            380     0.32
# target1                211     0.18
# provstate               90     0.07
# specificity              6     0.00
# ishostkid                3     0.00
# multiple                 1     0.00
# doubtterr                1     0.00
# INT_MISC                 0     0.00
# INT_IDEO                 0     0.00
# INT_LOG                  0     0.00
# dbsource                 0     0.00
# INT_ANY                  0     0.00
# iyear                    0     0.00
# property                 0     0.00
# weaptype1_txt            0     0.00
# iday                     0     0.00
# extended                 0     0.00
# country                  0     0.00
# country_txt              0     0.00
# region                   0     0.00
# region_txt               0     0.00
# vicinity                 0     0.00
# crit1                    0     0.00
# crit2                    0     0.00
# crit3                    0     0.00
# success                  0     0.00
# suicide                  0     0.00
# attacktype1              0     0.00
# attacktype1_txt          0     0.00
# targtype1                0     0.00
# targtype1_txt            0     0.00
# gname                    0     0.00
# imonth                   0     0.00
# weaptype1                0     0.00
# individual               0     0.00

# %% [markdown]
# ###  Identify the First Pass of Target Attributes
# Select the list of attributes that contain missing values of less than 20% and that are not duplicated by another attribute.

# %%
target_attrs = result[result['Percent'] < 20.0]
keep_attrs = target_attrs.index.values

# The nperps attribute contain 15.34% blank values.  However, an additional 85.66% are 
# coded (-99, -9) as unknown.
keep_attrs = keep_attrs[keep_attrs != 'nperps']
keep_attrs

# Remove attributes that duplicate another attribute
keep_attrs = keep_attrs[keep_attrs != 'country']
keep_attrs = keep_attrs[keep_attrs != 'region']
keep_attrs = keep_attrs[keep_attrs != 'attacktype1']
keep_attrs = keep_attrs[keep_attrs != 'targtype1']
keep_attrs = keep_attrs[keep_attrs != 'targsubtype1']
keep_attrs = keep_attrs[keep_attrs != 'natlty1']
keep_attrs = keep_attrs[keep_attrs != 'weaptype1']
keep_attrs = keep_attrs[keep_attrs != 'weapsubtype1']
# Out:
# array(['iyear', 'imonth', 'iday', 'extended', 'country', 'country_txt',
#        'region', 'region_txt', 'provstate', 'city', 'latitude',
#        'longitude', 'specificity', 'vicinity', 'summary', 'crit1',
#        'crit2', 'crit3', 'doubtterr', 'multiple', 'success', 'suicide',
#        'attacktype1', 'attacktype1_txt', 'targtype1', 'targtype1_txt',
#        'targsubtype1', 'targsubtype1_txt', 'corp1', 'target1', 'natlty1',
#        'natlty1_txt', 'gname', 'guncertain1', 'individual', 'nperpcap',
#        'claimed', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'nkill', 'nkillus', 'nkillter', 'nwound',
#        'nwoundus', 'nwoundte', 'property', 'ishostkid', 'scite1',
#        'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY'],
#       dtype=object)

# %% [markdown]
# ### Subset the Original Dataset
# Only include the attributes in the target set of attributes.

# %%
subset_df = gtd_df.loc[:, keep_attrs]
subset_df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120439 entries, 199601000001 to 201712310032
# Data columns (total 47 columns):
# iyear               120439 non-null int64
# imonth              120439 non-null int64
# iday                120439 non-null int64
# extended            120439 non-null int64
# country_txt         120439 non-null object
# region_txt          120439 non-null object
# provstate           120349 non-null object
# city                120005 non-null object
# latitude            119155 non-null float64
# longitude           119155 non-null float64
# specificity         120433 non-null float64
# vicinity            120439 non-null int64
# summary             114233 non-null object
# crit1               120439 non-null int64
# crit2               120439 non-null int64
# crit3               120439 non-null int64
# doubtterr           120438 non-null float64
# multiple            120438 non-null float64
# success             120439 non-null int64
# suicide             120439 non-null int64
# attacktype1_txt     120439 non-null object
# targtype1_txt       120439 non-null object
# targsubtype1_txt    112839 non-null object
# corp1               107274 non-null object
# target1             120228 non-null object
# natlty1_txt         119230 non-null object
# gname               120439 non-null object
# guncertain1         120059 non-null float64
# individual          120439 non-null int64
# nperpcap            110871 non-null float64
# claimed             114235 non-null float64
# weaptype1_txt       120439 non-null object
# weapsubtype1_txt    109706 non-null object
# nkill               116035 non-null float64
# nkillus             114025 non-null float64
# nkillter            111619 non-null float64
# nwound              111916 non-null float64
# nwoundus            113819 non-null float64
# nwoundte            109774 non-null float64
# property            120439 non-null int64
# ishostkid           120436 non-null float64
# scite1              114171 non-null object
# dbsource            120439 non-null object
# INT_LOG             120439 non-null int64
# INT_IDEO            120439 non-null int64
# INT_MISC            120439 non-null int64
# INT_ANY             120439 non-null int64
# dtypes: float64(15), int64(16), object(16)
# memory usage: 44.1+ MB

# %% [markdown]
# ### Fix Missing Values
# The code book is not consistent when classify missing or unknown values. The original data included, blanks, -9, an -99.  For consistency, -1 is used for categorical attributes that are numeric and UNKNOWN is used for categorical attributes that are text.  Numeric attributes that contain coded missing values are replaced with NAN.

# %%
# Categorical Variables
# ---------------------
subset_df['specificity'].fillna(-1, inplace=True)

subset_df.loc[subset_df['vicinity'] == -9, 'vicinity'] = -1

subset_df.loc[subset_df['doubtterr'] == -9, 'doubtterr'] = -1

subset_df['targsubtype1_txt'].fillna('UNKNOWN', inplace=True)

subset_df['natlty1_txt'].fillna('UNKNOWN', inplace=True)

subset_df['guncertain1'].fillna(-1, inplace=True)

subset_df['claimed'].fillna(-1, inplace=True)
subset_df.loc[subset_df['claimed'] == -9, 'claimed'] = -1

subset_df['weapsubtype1_txt'].fillna('UNKNOWN', inplace=True)

subset_df.loc[subset_df['property'] == -9, 'property'] = -1

subset_df['ishostkid'].fillna(-1, inplace=True)
subset_df.loc[subset_df['ishostkid'] == -9, 'ishostkid'] = -1

subset_df.loc[subset_df['INT_LOG'] == -9, 'INT_LOG'] = -1

subset_df.loc[subset_df['INT_IDEO'] == -9, 'INT_IDEO'] = -1

subset_df.loc[subset_df['INT_MISC'] == -9, 'INT_MISC'] = -1

subset_df.loc[subset_df['INT_ANY'] == -9, 'INT_ANY'] = -1


# Numeric Variables
# -----------------
subset_df.loc[subset_df['nperpcap'] == -9, 'nperpcap'] = np.nan
subset_df.loc[subset_df['nperpcap'] == -99, 'nperpcap'] = np.nan


# Text Variables
# --------------
subset_df['provstate'].fillna('UNKNOWN', inplace=True)
subset_df['city'].fillna('UNKNOWN', inplace=True)
subset_df.loc[subset_df['city'] == 'Unknown', 'city'] = 'UNKNOWN'
subset_df['summary'].fillna('UNKNOWN', inplace=True)
subset_df['corp1'].fillna('UNKNOWN', inplace=True)
subset_df['target1'].fillna('UNKNOWN', inplace=True)
subset_df['scite1'].fillna('UNKNOWN', inplace=True)

# %% [markdown]
# ## Map Yes/No/Unknown Codes
# Many attributes contain codes of 1, 0, -1 to represent Yes, No, and Unknown.  Replace the codes with labels to improve exploratory data analysis.

# %%
# Map the codes to labels
ynu_map = {1: 'YES', 0: 'NO', -1: 'UKNOWN'}

# List of target attributes to map
ynu_attrs =['extended', 'vicinity', 'crit1', 'crit2', 'crit3', 'doubtterr', 'multiple', 
            'success', 'suicide', 'guncertain1', 'individual', 'claimed', 'property', 
            'ishostkid', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY']

# Iterate over each target attribute and map it
for att in ynu_attrs:
    att_txt = att + '_txt'
    subset_df[att_txt] = subset_df[att].map(ynu_map)

# Get the list of attributes, dropping the coded for labeled attributes
final_attrs = []

for attr in subset_df.columns.values:
    if attr not in ynu_attrs:
        final_attrs.append(attr)
        
subset_df2 = subset_df.loc[:, final_attrs]
subset_df2.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120439 entries, 199601000001 to 201712310032
# Data columns (total 47 columns):
# iyear               120439 non-null int64
# imonth              120439 non-null int64
# iday                120439 non-null int64
# country_txt         120439 non-null object
# region_txt          120439 non-null object
# provstate           120439 non-null object
# city                120439 non-null object
# latitude            119155 non-null float64
# longitude           119155 non-null float64
# specificity         120439 non-null float64
# summary             120439 non-null object
# attacktype1_txt     120439 non-null object
# targtype1_txt       120439 non-null object
# targsubtype1_txt    120439 non-null object
# corp1               120439 non-null object
# target1             120439 non-null object
# natlty1_txt         120439 non-null object
# gname               120439 non-null object
# nperpcap            109959 non-null float64
# weaptype1_txt       120439 non-null object
# weapsubtype1_txt    120439 non-null object
# nkill               116035 non-null float64
# nkillus             114025 non-null float64
# nkillter            111619 non-null float64
# nwound              111916 non-null float64
# nwoundus            113819 non-null float64
# nwoundte            109774 non-null float64
# scite1              120439 non-null object
# dbsource            120439 non-null object
# extended_txt        120439 non-null object
# vicinity_txt        120439 non-null object
# crit1_txt           120439 non-null object
# crit2_txt           120439 non-null object
# crit3_txt           120439 non-null object
# doubtterr_txt       120438 non-null object
# multiple_txt        120438 non-null object
# success_txt         120439 non-null object
# suicide_txt         120439 non-null object
# guncertain1_txt     120439 non-null object
# individual_txt      120439 non-null object
# claimed_txt         120439 non-null object
# property_txt        120439 non-null object
# ishostkid_txt       120439 non-null object
# INT_LOG_txt         120439 non-null object
# INT_IDEO_txt        120439 non-null object
# INT_MISC_txt        120439 non-null object
# INT_ANY_txt         120439 non-null object
# dtypes: float64(10), int64(3), object(34)
# memory usage: 44.1+ MB

# %% [markdown]
# ### Save the Preprocessed Data
# Output the new data frame to a CSV file.

# %%
subset_df2.to_csv("../Data/gtd_preprocessed_1997to2017.csv", sep = ",")
